# %% [markdown]
# # Notebook example 1

# %% [markdown]
# This is a simple notebook that will also show up in the sphinx documentation because of the file:
# `{{cookiecutter.pypi_package_name}}/docs/notebooks/notebook1.ipynb`
# (which references this notebook via relative path `../../notebooks/notebook1.ipynb`)
#
# ...that file is then referenced as `notebooks/notebook1` in the restructured text file:
# `{{cookiecutter.pypi_package_name}}/docs/notebooks.rst`
#
# ...which is referenced as `notebooks` in:
# `{{cookiecutter.pypi_package_name}}/docs/index.rst`

# %%
print("HELLO WORLD! This is notebook1.ipynb!")
# Out:
# HELLO WORLD! This is notebook1.ipynb!
